# %% [markdown]
# # Troubleshooting Q and A
#
# This section is all about fixing problems and errors in your python program.

# %% [markdown]
# # How to Read Python Error Messages
#
# Python error messages
# TypeError: Can't convert 'int' object to str implicitly
# Above the error message is the "traceback" also called the "call stack". This is a representation of the sequence of procedure calls that lead to the error. If the procedure call originated from code from a file, the filename would be listed after the word "File" on each line. If the procedure call originated from a notebook cell, then the word "ipython-input-#-HEX".

# %%
# Problem 1
a= input("Please put a number")

if a < 3:
   print("Won")
else
   print("Lost")

# %%
# Problem 2
import pnadas as pd
df = Pd.read_csv("Exp_TCGA.csv")
df.shape

# %%
# Problem 3
import pandas as pd

# Load the data
df = pd.read_csv("Exp_TCGA.csv")

for index, row in df.iterrows():
    print row
    if index == 1:
        break

# %%
# Problem 4
odd = lambda x : bool(x % 2)

numbers = [n for n in range(20)]
for i in range(len(numbers)):
  if odd(numbers[i]):
      del numbers[i]
  else:
    print(numbers[i])

# %%
# Problem 5
import numpy as np 
import pandas as pd

# Load the data
df = pd.read_csv("Exp_TCGA.csv")

# Note we are still using the df data above
ax = np.log2(df["S4"]).plot.hist(bins=40)

# %%
# Problem 6
""" def powers(x):
    "
    Return a few powers of x.
    "
    return x ** 2, x ** 3, x ** 4
"""

power(5)

# %%
# Problem 7
a, b = 0, 1
while a < 10:
     print(a)
 a, b = b, a+b

# %%
# Problem 8
li = ("abc", 22, 4.34, 23)
li[1] = 983

# %%
# Problem 9

def add(x, y):
    return x + y

#
add(x=3)

# %%
# Problem 10
se = {2, 3, 5, 5, 6, 8}
se[3] # Trying to return the 3 item
