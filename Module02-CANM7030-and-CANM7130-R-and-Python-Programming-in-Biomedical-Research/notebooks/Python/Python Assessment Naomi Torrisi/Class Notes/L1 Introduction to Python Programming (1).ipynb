# %% [markdown]
# # Introduction to Python Programming
#
# We will be using the Jupyter notebook for all activies. Every notebook has an associated language called the "kernel". We will be using in the Python 3 kernel that you installed before.
#
# For more information on how to use the notebook, please read the following :
# https://docs.jupyter.org/en/latest/
#
# **Python**
#
# Python is a programming language that has been under development for many years.
#
# * A) This notebook will cover:
# * B) Python data types
# * C) Variables
# * D) Arithmetic operations
# * E) Strings
# * F) Print
# * G) Commenting on codes
#
# Python documentation:
# https://docs.python.org/3/index.html

# %% [markdown]
# # Statements
#
# Python is a computer language based on statements.
# In fact programs in Python consists of lines composed of stattements.
#
# Different types of statements are possible:
# 1. single expression
# 2. assignment
# 3. function call
# 4. function and class definition
# 5. statement * 2

# %%
# We could use Python as a calculator, albeit a fancy calculator.

# Consider the below statments
10 * 4

# %% [markdown]
# The Python interpreter acts as a simple calculator: you can type an expression at it and it will write the value. Expression syntax is straightforward: the operators +, -, * and / work just like in most other languages.

# %%
"Hello"

# %%
str(20) + "_hello"

# %% [markdown]
# # Variables
#
# The calculator will be more useful if we can make it store values. We solve this problem by defining variables
# Variables can be called by their names (even if you misspell it). Note: Python variables are case sensitive and unique.
#
# Consider the below variables:

# %%
apple = 10
orange = 5
Totalfruit = apple + orange
Totalfruit

# %%
# We can now reuse the variables in a different code block without having to define it again!
apple / 3

# %% [markdown]
# Division (/) always returns a float. To do floor division and get an integer result you can use the // operator; to calculate the remainder you can use %:

# %% [markdown]
# # Data types
#
# Variables have a type, which defines the way they are stored in memory.
#
# The basic types are used below.

# %%
# Integer
5
int(5)

# %%
# Float
3.2 
float(3.2)

# %%
# String
"Hello"
str("Hello")

# %%
# Boolean
True
bool(True)

# %%
# None type
None

# %% [markdown]
# Remember:
# We can't do arithmetic operations on variables of different types.
# Make sure that you are always aware of your variable types!
# Consider the below code :

# %%
apple = 10
orange = "5"
apple + orange

# %% [markdown]
# The above gave a "TypeError". Python Errors have tags and this makes it easy to find out the issue.

# %% [markdown]
# # Casting Types
#
# In python we can convert variables to different types. CASTING ! – the operation of converting between types.
# You can do this with :
# int(), float(), str() and bool().

# %%
apple = 10
orange = "5"
apple + int(orange) # Cast orange to integer to solve the error.

# %% [markdown]
# # Comparison operators
#
# These include, ==, !=, <, >, <=, >=. We can use that to return boolean (True or False). Very useful if you want to create a conditional statement.
#
# Example of comparison:

# %%
apple = 10
apple == 10

# %%
apple > 30

# %%
# We can also combine the operators in interesting ways.
# For example you can check if the number of apple is between a range

# %%
(apple > 2) and (apple < 11)

# %% [markdown]
# # Logical operators
# These include or, and, not. They return boolen and allows you to extend the comparison operators.
# For example we can use it to do this:

# %%
not((apple == 1) and (apple == 10))

# %% [markdown]
# Logical operators are so useful and they allow you to write readable codes.

# %% [markdown]
# # More on Strings
#
# Python is one of the best handlers of strings
# 1. Can be added
# 2. Can be multiplied
# 3. Can be multiple lines
# 4. Etc
# 5. The have methods (we will speak more above class)

# %%
# Consider the output of these operations
A = "apple"
B = "orange"
A + " " + B + " and " + A

# %%
# You can multiple the string
A * 3

# %%
# Methods add extra functionality to the string data type
# You can check the methods as below :
dir("A")

# %%
# Notice that is extensive
# Lets use some of them
A.upper()

# %%
C = "Apple"
C.lower()

# %%
C.lower() + " " + A.upper()

# %% [markdown]
# # Print
# When writing scripts and multiline code in jupyter your outcomes aren't printed.
# You must use the print() function.
#
# In Python, a function is a group of related statements that performs a specific task. Functions help break our program into smaller and modular chunks.

# %%
# Example 
3+4
8-2
10*2

# %%
# Notice that the above code only displayed the last operation/statment
# We can fix that with 
print(3+4)
print(8-2)
print(10*2)

# %% [markdown]
# Some times we have multiline string or want to output multilines. Python have several ways of doing this including:

# %%
str1 = """
This allows you to put multiple lines
Then the next line is here
yet another line here
"""


str2 = "Alternatively you can use the special \n character to \n split the text \n into lines - '\\n' is not printed"
print(str1)
print("   ")
print(str2)

# %% [markdown]
# # Placeholders
#
# Python has a cool utility that allows you to add things to string using placeholder. This comes in handy if you have a text you want to update on demand.

# %%
# For example
print("We have {} apples and {} oranges".format(10, 20))

# %% [markdown]
# # Commenting
#
# You would have noticed the use of "#" through the notebook. This indicates where we put a comment and allows python to skip it. Note that in the markdown mode it indicates a header.
#
# Comments are useful for your future self and anybody else to understand your code.
# They are also useful for temporarily removing codes from execution. Consider the below code:

# %%
# Lets define the number of apples
apple = 10
orange = 30 # This is the number of oranges
# Below we set another orange but commented out
# orange = 15
print(apple + orange) # Finally we print it

# %% [markdown]
# # Self practice
#
# You have now learnt the basic of python and you are ready to begin you journey.
# Complete the below tasks to test your knowledge
#
# 1. Insert a code block. **[Hint: See lecture slide on Jupyter notebook]**
# 2. Insert a markdown block. **[Hint: See lecture slide on Jupyter notebook]**
# 3. Write an expression that uses all the python data types. **[Hint: See lecture slide Data types]**
# 4. Write a statement that uses two comparison operator and two logical operators. **[Hint: See sections Comparison operator and Logical operator]**
# 5. Given this DNA sequence "CGC_TAGCG_TT", print the complete sequence using a place holder (You can use any base for the missing two. **[Hint: See section More on string]**
# 6. Calculate the average age of 5 of your friends. **[Hint: See lecture slides]**
# 7. Write 10 lines of code with anything you want and demonstrate the different ways to commment a code.
# 8. Calculate square root of 20 divided by 4. **[Hint: Review the lecture and practical. Search online]**
# 9. Assign values to variables v1 and v2 examine the result of the expression v1+v2/v2, which operation occurred first and why?. **[Hint: See lecture on mathematical operations and ordering]**
#
# # Remember to use markdown to comment on what you are doing.
